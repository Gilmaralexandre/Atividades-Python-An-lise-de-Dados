# %% [markdown]
# ## Exercícios

# %% [markdown]
# __Objetivo deste notebook é aprimorar e exercitar os aprendizados de pandas respondendo algumas perguntas sobre o conjunto de dados.__

# %% [markdown]
# Link para Dataset: https://www.kaggle.com/datasets/matheusfreitag/gas-prices-in-brazil

# %%
#Importando os datasets
import pandas as pd
import numpy as np

gs2000 = pd.read_csv("Datasets/gasolina_2000+.csv",index_col = 0)
gs2000.head()
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  \
# 0                1.288                  0.016                  1.19
# 1                1.162                  0.114                  0.89
# 2                1.389                  0.097                  1.18
# 3                1.262                  0.070                  1.09
# 4                1.181                  0.078                  1.05
#
#    PREÇO MÁXIMO REVENDA MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# 0                 1.350                0.463                     0.012
# 1                 1.449                0.399                     0.098
# 2                 1.760                0.419                     0.070
# 3                 1.509                0.432                     0.055
# 4                 1.400                 0.24                     0.066
#
#   PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                    0.825                       0.11
# 1                    0.763                      0.088
# 2                     0.97                      0.095
# 3                     0.83                      0.119
# 4                    0.941                      0.077
#
#   PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                    0.4201                    0.9666
# 1                    0.5013                      1.05
# 2                    0.5614                     1.161
# 3                    0.5991                   1.22242
# 4                    0.7441                    1.0317
#
#   COEF DE VARIAÇÃO DISTRIBUIÇÃO
# 0                         0.133
# 1                         0.115
# 2                         0.098
# 3                         0.143
# 4                         0.082

# %%
gs2010 = pd.read_csv("Datasets/gasolina_2010+.csv", low_memory=False, index_col = 0)
gs2010.head()
# Out:
#      DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 9256   2011-01-02  2011-01-08  CENTRO OESTE    DISTRITO FEDERAL
# 9257   2011-01-02  2011-01-08  CENTRO OESTE               GOIAS
# 9258   2011-01-02  2011-01-08  CENTRO OESTE         MATO GROSSO
# 9259   2011-01-02  2011-01-08  CENTRO OESTE  MATO GROSSO DO SUL
# 9260   2011-01-02  2011-01-08      NORDESTE             ALAGOAS
#
#                PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 9256  ETANOL HIDRATADO                            80              R$/l
# 9257  ETANOL HIDRATADO                           255              R$/l
# 9258  ETANOL HIDRATADO                           141              R$/l
# 9259  ETANOL HIDRATADO                           132              R$/l
# 9260  ETANOL HIDRATADO                            97              R$/l
#
#       PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  \
# 9256                2.030                  0.003                 2.020
# 9257                1.717                  0.102                 1.490
# 9258                1.848                  0.148                 1.590
# 9259                1.893                  0.108                 1.699
# 9260                2.026                  0.084                 1.749
#
#       PREÇO MÁXIMO REVENDA MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# 9256                 2.050                0.411                     0.001
# 9257                 1.990                0.225                     0.059
# 9258                 2.490                0.326                     0.080
# 9259                 2.199                0.191                     0.057
# 9260                 2.100                0.268                     0.041
#
#      PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 9256                    1.619                      0.013
# 9257                    1.492                      0.069
# 9258                    1.522                      0.105
# 9259                    1.702                       0.04
# 9260                    1.758                      0.042
#
#      PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 9256                    1.6111                    1.6411
# 9257                    1.3221                    1.6201
# 9258                    1.2833                    1.7486
# 9259                    1.5915                      1.79
# 9260                      1.63                     1.848
#
#      COEF DE VARIAÇÃO DISTRIBUIÇÃO
# 9256                         0.008
# 9257                         0.046
# 9258                         0.069
# 9259                         0.024
# 9260                         0.024

# %% [markdown]
# ## Neste projeto, trabalharemos com dois arquivos csvs separados, contendo informações sobre o preço da gasolina no Brasil.
#
# ### 1. Carregue os conjuntos de dados "gasolina_2000+.csv" e "gasolina_2010+.csv" em dois DataFrames diferentes e combine-os em um único DataFrame.

# %%
df = pd.concat([gs2000,gs2010])
df.head() #A função pd.concat pode ser estilizada pelo axis
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  \
# 0                1.288                  0.016                  1.19
# 1                1.162                  0.114                  0.89
# 2                1.389                  0.097                  1.18
# 3                1.262                  0.070                  1.09
# 4                1.181                  0.078                  1.05
#
#    PREÇO MÁXIMO REVENDA MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# 0                 1.350                0.463                     0.012
# 1                 1.449                0.399                     0.098
# 2                 1.760                0.419                     0.070
# 3                 1.509                0.432                     0.055
# 4                 1.400                 0.24                     0.066
#
#   PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                    0.825                       0.11
# 1                    0.763                      0.088
# 2                     0.97                      0.095
# 3                     0.83                      0.119
# 4                    0.941                      0.077
#
#   PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                    0.4201                    0.9666
# 1                    0.5013                      1.05
# 2                    0.5614                     1.161
# 3                    0.5991                   1.22242
# 4                    0.7441                    1.0317
#
#   COEF DE VARIAÇÃO DISTRIBUIÇÃO
# 0                         0.133
# 1                         0.115
# 2                         0.098
# 3                         0.143
# 4                         0.082

# %%
#verificando o tamanho do dataframe
print(gs2000.shape)
print(gs2010.shape)

print(df.shape)
# Out:
# (42638, 18)
# (78185, 18)
# (120823, 18)

# %% [markdown]
# ### 2.Investigue as colunas e entenda o conjunto de dados usando o head() e info()

# %%
df.info()

# com esta função é possível ver o tipo de dados por coluna, ver o tamanho e espaço utilizado na memória.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 120823 entries, 0 to 120822
# Data columns (total 18 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   DATA INICIAL                   120823 non-null  object
#  1   DATA FINAL                     120823 non-null  object
#  2   REGIÃO                         120823 non-null  object
#  3   ESTADO                         120823 non-null  object
#  4   PRODUTO                        120823 non-null  object
#  5   NÚMERO DE POSTOS PESQUISADOS   120823 non-null  int64
#  6   UNIDADE DE MEDIDA              120823 non-null  object
#  7   PREÇO MÉDIO REVENDA            120823 non-null  float64
#  8   DESVIO PADRÃO REVENDA          120823 non-null  float64
#  9   PREÇO MÍNIMO REVENDA           120823 non-null  float64
#  10  PREÇO MÁXIMO REVENDA           120823 non-null  float64
#  11  MARGEM MÉDIA REVENDA           120823 non-null  object
#  12  COEF DE VARIAÇÃO REVENDA       120823 non-null  float64
#  13  PREÇO MÉDIO DISTRIBUIÇÃO       120823 non-null  object
#  14  DESVIO PADRÃO DISTRIBUIÇÃO     120823 non-null  object
#  15  PREÇO MÍNIMO DISTRIBUIÇÃO      120823 non-null  object
#  16  PREÇO MÁXIMO DISTRIBUIÇÃO      120823 non-null  object
#  17  COEF DE VARIAÇÃO DISTRIBUIÇÃO  120823 non-null  object
# dtypes: float64(5), int64(1), object(12)
# memory usage: 17.5+ MB

# %% [markdown]
# ### 3. Selecione a terceira entrada da coluna DATA INICIAL e verifique seu tipo.

# %%
type(df['DATA INICIAL'].iloc[2])
#Observando o tipo de dados
# Out:
# str

# %% [markdown]
# ### 4. Você deve ter percebido que as colunas DATA INICIAL e DATA FINAL estão formatadas como string. Utilizando o método pd.to_datetime(), converta ambas colunas para Timestamp / Datetime.

# %%
#Convertendo a coluna para Datetime com a função pd.to_datetime/ caso não fosse pelo pandas a conversão pode ser feita importando
# a lib Datetime
df['DATA INICIAL'] = pd.to_datetime(df['DATA INICIAL'])
df['DATA FINAL'] = pd.to_datetime(df['DATA FINAL'])

# %%
type(df["DATA INICIAL"].iloc[2])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %% [markdown]
# ### 5. Crie uma nova coluna para representar o ano e o mês(aaaa-mm), utilizando a coluna DATA FINAL como referência.

# %%
#Acessando a coluna já convertida e pegando as informações de ano e mes
df['MES_ANO'] = df["DATA FINAL"].dt.strftime('%Y %m')

# %%
#Outra possibilidade seria aplicando uma função em tempo de execução conforme realizado abaixo.

df["MES_ANO"] = df["DATA FINAL"].apply(lambda x: "{}".format(x.year)) + df["DATA FINAL"].apply(lambda x: "-{:02d}".format(x.month))

# %%
df.head()
# Out:
#   DATA INICIAL DATA FINAL        REGIÃO              ESTADO           PRODUTO  \
# 0   2004-05-09 2004-05-15  CENTRO OESTE    DISTRITO FEDERAL  ETANOL HIDRATADO
# 1   2004-05-09 2004-05-15  CENTRO OESTE               GOIAS  ETANOL HIDRATADO
# 2   2004-05-09 2004-05-15  CENTRO OESTE         MATO GROSSO  ETANOL HIDRATADO
# 3   2004-05-09 2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL  ETANOL HIDRATADO
# 4   2004-05-09 2004-05-15      NORDESTE             ALAGOAS  ETANOL HIDRATADO
#
#    NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 0                           127              R$/l                1.288
# 1                           387              R$/l                1.162
# 2                           192              R$/l                1.389
# 3                           162              R$/l                1.262
# 4                           103              R$/l                1.181
#
#    DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# 0                  0.016                  1.19                 1.350
# 1                  0.114                  0.89                 1.449
# 2                  0.097                  1.18                 1.760
# 3                  0.070                  1.09                 1.509
# 4                  0.078                  1.05                 1.400
#
#   MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                0.463                     0.012                    0.825
# 1                0.399                     0.098                    0.763
# 2                0.419                     0.070                     0.97
# 3                0.432                     0.055                     0.83
# 4                 0.24                     0.066                    0.941
#
#   DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                       0.11                    0.4201
# 1                      0.088                    0.5013
# 2                      0.095                    0.5614
# 3                      0.119                    0.5991
# 4                      0.077                    0.7441
#
#   PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO  MES_ANO
# 0                    0.9666                         0.133  2004-05
# 1                      1.05                         0.115  2004-05
# 2                     1.161                         0.098  2004-05
# 3                   1.22242                         0.143  2004-05
# 4                    1.0317                         0.082  2004-05

# %% [markdown]
# ### 6. Utilizando o value_counts(), liste todos os tipos de produtos contidos na base de dados.

# %%
df.PRODUTO.value_counts()
# Out:
# GASOLINA COMUM        23570
# GLP                   23561
# ETANOL HIDRATADO      23440
# ÓLEO DIESEL           21194
# GNV                   14469
# ÓLEO DIESEL S10        9113
# OLEO DIESEL S10        2376
# OLEO DIESEL            2351
# GASOLINA ADITIVADA      749
# Name: PRODUTO, dtype: int64

# %% [markdown]
# ### 7. Filtre o DataFrame para obter apenas dados da 'GASOLINA COMUM'. Grave em uma nova variável.

# %%
#neste exemplo realizo slice ou fatiamento dos dados com o objetivo de formatar conforme desejado
df2= df[df["PRODUTO"] == 'GASOLINA COMUM']

# %%
df2.head(5)
df2.shape
# Out:
# (23570, 19)

# %% [markdown]
# ### 8. Qual o preço médio de revenda da gasolina em agosto de 2008?

# %%
df.columns
# Out:
# Index(['DATA INICIAL', 'DATA FINAL', 'REGIÃO', 'ESTADO', 'PRODUTO',
#        'NÚMERO DE POSTOS PESQUISADOS', 'UNIDADE DE MEDIDA',
#        'PREÇO MÉDIO REVENDA', 'DESVIO PADRÃO REVENDA', 'PREÇO MÍNIMO REVENDA',
#        'PREÇO MÁXIMO REVENDA', 'MARGEM MÉDIA REVENDA',
#        'COEF DE VARIAÇÃO REVENDA', 'PREÇO MÉDIO DISTRIBUIÇÃO',
#        'DESVIO PADRÃO DISTRIBUIÇÃO', 'PREÇO MÍNIMO DISTRIBUIÇÃO',
#        'PREÇO MÁXIMO DISTRIBUIÇÃO', 'COEF DE VARIAÇÃO DISTRIBUIÇÃO',
#        'MES_ANO'],
#       dtype='object')

# %%
# no Pandas a estrutura é a mesma que no Python
#Então as funções são passadas com parenteses(quase sempre exceto as funções internas) e nos casos de mais de um parametro em muitas vezes usamos listas.

df2[df2['MES_ANO']== '2008-08']['PREÇO MÉDIO REVENDA'].mean()
# Out:
# 2.6012444444444447

# %% [markdown]
# ### 9. Qual o preço médio de revenda da gasolina em maio de 2014 em São Paulo?

# %%
#Neste caso o filtro é pela coluna Mes_ano == 08-2008 e Estado == São Paulo passado com [()]
#Depois utilizamos media da coluna Preço media revenda

df2[(df2["MES_ANO"] == '2008-08') & (df2["ESTADO"] == 'SAO PAULO')]["PREÇO MÉDIO REVENDA"].mean()
# Out:
# 2.4046

# %% [markdown]
# ### 10. Você conseguiria descobrir em qual(quais) estado(s) a gasolina ultrapassou a barreira dos R$ 5,00? E quando isso ocorreu?

# %%
#Neste exemplo pode ser passado condiçoes lógicas dentro do código

df2[df2["PREÇO MÉDIO REVENDA"] > 5][["ESTADO", "MES_ANO", "PREÇO MÉDIO REVENDA"]].head(5)
# Out:
#                ESTADO  MES_ANO  PREÇO MÉDIO REVENDA
# 98201            ACRE  2018-05                5.053
# 98347            ACRE  2018-06                5.035
# 98493            ACRE  2018-06                5.038
# 98511  RIO DE JANEIRO  2018-06                5.016
# 98646            ACRE  2018-06                5.031

# %% [markdown]
# ### 11. Qual a média de preço dos estados da região sul em 2012?

# %%
# criando um df aux, uso a função lambda para pegar o ano == 2012
# Logo após faço o filtro regiaão == sul 
# Depois utilizamos media da coluna Preço media revenda

df_aux = df2[(df2["DATA FINAL"].apply(lambda x: x.year) == 2012)]
df_aux[df_aux["REGIÃO"] == "SUL"]["PREÇO MÉDIO REVENDA"].mean()
# Out:
# 2.7214423076923073

# %% [markdown]
# ### 12. Você conseguiria obter uma tabela contendo a variação percentual ano a ano para o estado do Rio de Janeiro?

# %%
# Com a mesma lógica usada anteriormente
# uso a função lambda para pegar o mes
# e os dados referentes ao RJ

df2["MES"] = df2["DATA FINAL"].apply(lambda x: x.month)
df_rio = df2[df2["ESTADO"] == "RIO DE JANEIRO"]
# Out:
# C:\Users\gilma\AppData\Local\Temp\ipykernel_256\2866652320.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2["MES"] = df2["DATA FINAL"].apply(lambda x: x.month)

# %%
# a FUNÇÃO GROUPBY uni a informação da coluna Mes ano
# a função last pega o ultimo valor

df_month_rio = df_rio.groupby("MES_ANO")[["PREÇO MÉDIO REVENDA", "MES"]].last()

# %%
#estudar sobre esta função
(df_month_rio[df_month_rio["MES"] == 12] / df_month_rio[df_month_rio["MES"] == 12].shift(1) - 1) * 100
# Out:
#          PREÇO MÉDIO REVENDA  MES
# MES_ANO
# 2004-12                  NaN  NaN
# 2005-12             9.233449  0.0
# 2006-12             0.917065  0.0
# 2007-12             0.355591  0.0
# 2008-12             0.984252  0.0
# 2009-12             1.637427  0.0
# 2010-12             2.032988  0.0
# 2011-12             7.105263  0.0
# 2012-12             0.982801  0.0
# 2013-12             6.777894  0.0
# 2014-12             4.361979  0.0
# 2015-12            20.461634  0.0
# 2016-12             3.625065  0.0
# 2017-12            13.643178  0.0
# 2018-12             5.804749  0.0
# 2019-12             3.802993  0.0
# 2020-12            -1.321321  0.0

# %% [markdown]
# ### DESAFIO: Crie uma tabela contendo uma serie temporal com a diferença absoluta e percentual entre os valores mais baratos e caros. Apresente também ao lado os estados na qual os maiores e menores preços foram registrados.

# %%
df_max = df2.groupby("MES_ANO").max()["PREÇO MÉDIO REVENDA"].sort_index()
idx_max = df2.groupby('MES_ANO')["PREÇO MÉDIO REVENDA"].idxmin()

df_min = df2.groupby("MES_ANO").min()["PREÇO MÉDIO REVENDA"].sort_index()
idx_min = df2.groupby('MES_ANO')["PREÇO MÉDIO REVENDA"].idxmax()
df_diff = pd.DataFrame()

# %%
idx_max
# Out:
# MES_ANO
# 2004-05     12114
# 2004-06     12168
# 2004-07     12334
# 2004-08     12411
# 2004-09     12600
#             ...
# 2021-01    117685
# 2021-02    118739
# 2021-03    119271
# 2021-04    120344
# 2021-05    120701
# Name: PREÇO MÉDIO REVENDA, Length: 204, dtype: int64

# %%
df_diff["abs_diff"] = df_max - df_min
df_diff["perct_diff"] = (df_max - df_min) / df_min * 100
df_diff["max"] = df_max
df_diff["min"] = df_min

# %%
df2.loc[idx_max, :][["ESTADO", "PREÇO MÉDIO REVENDA", "MES_ANO"]]
# Out:
#                   ESTADO  PREÇO MÉDIO REVENDA  MES_ANO
# 12114          SAO PAULO                1.888  2004-05
# 12168          SAO PAULO                1.912  2004-06
# 12334   DISTRITO FEDERAL                1.936  2004-07
# 12411          SAO PAULO                2.030  2004-08
# 12600          SAO PAULO                2.031  2004-09
# ...                  ...                  ...      ...
# 117685             AMAPA                3.830  2021-01
# 118739             AMAPA                4.121  2021-02
# 119271             AMAPA                4.579  2021-03
# 120344             AMAPA                4.777  2021-04
# 120701             AMAPA                4.867  2021-05
#
# [204 rows x 3 columns]

# %%
df_diff["ESTADO_MAX"] = df2.loc[idx_max, :]["ESTADO"].values
df_diff["ESTADO_MIN"] = df2.loc[idx_min, :]["ESTADO"].values

# %%
df_diff["ESTADO_MAX"].value_counts()
# Out:
# SAO PAULO              40
# AMAPA                  38
# PIAUI                  28
# PARAIBA                28
# PARANA                 14
# AMAZONAS               14
# DISTRITO FEDERAL       12
# MARANHAO                9
# SANTA CATARINA          6
# PERNAMBUCO              4
# MATO GROSSO DO SUL      3
# RIO GRANDE DO NORTE     2
# GOIAS                   2
# CEARA                   2
# BAHIA                   2
# Name: ESTADO_MAX, dtype: int64

# %%
df_diff["ESTADO_MIN"].value_counts()
# Out:
# ACRE              166
# MATO GROSSO        25
# RIO DE JANEIRO     11
# RORAIMA             2
# Name: ESTADO_MIN, dtype: int64
